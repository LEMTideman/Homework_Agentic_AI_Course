# %%
# Configure Logfire & Instrument Pydantic AI
from pydantic_ai import Agent
from dotenv import load_dotenv
load_dotenv()

import logfire
logfire.configure()
logfire.instrument_pydantic_ai()
# The Logfire dashboard is available at https://logfire-eu.pydantic.dev/leotideman/starter-project
# Out:
# Logfire project URL: ]8;id=402326;https://logfire-eu.pydantic.dev/leotideman/starter-project\https://logfire-eu.pydantic.dev/leotideman/starter-project]8;;\

# %%
# Test tools
#from trivia_tools import TriviaTools
#tools = TriviaTools()
#print(tools.get_categories())
#print(tools.get_questions(amount=3, category=9, difficulty="easy"))

# %%
from trivia_agent import agent

# %%
#result = await agent.run("Let's play 3 medium questions from History") 
#print(result.output)

# %%
async def run(prompt):
    message_history = []

    while True:
        result = await agent.run(prompt, message_history=message_history)
        print(result.output)
        message_history = result.all_messages()

        prompt = input("You (write 'stop' to stop): ")
        if not prompt or prompt.lower().strip() == 'stop':
            break

# %%
await run("Let's play 5 easy questions from Science & Nature")

# %%
# Grouping Logfire traces
with logfire.span('trivia_session'):
    await run("Let's play 5 easy questions from Science & Nature")
# Out:
# 21:11:00.720 trivia_session
# 21:11:00.726   agent run
# 21:11:00.748     chat gpt-4o-mini
# 21:11:02.062     running 1 tool
# 21:11:02.062       running tool: get_categories
# 21:11:02.531     chat gpt-4o-mini
# 21:11:03.367     running 1 tool
# 21:11:03.367       running tool: get_questions
# 21:11:03.762     chat gpt-4o-mini
# Great! Let's start the quiz with your first question.
#
# ### Question 1:
# What does LASER stand for?
# A) Lite analysing by stereo ecorazer
# B) Light amplifier by standby energy of radio
# C) Light amplification by stimulated emission of radiation
# D) Life antimatter by standing entry of range
#
# What's your answer? (A, B, C, or D)
# You (write 'stop' to stop):  Light amplification by stimulated emission of radiation
# 21:11:38.066   agent run
# 21:11:38.066     chat gpt-4o-mini
# Correct! 🎉
#
# LASER stands for "Light amplification by stimulated emission of radiation." This technology is widely used in various applications, from barcode scanners to laser surgery and even in cutting materials. Fun fact: The first laser was invented in 1960 by Theodore Maiman, using a ruby crystal!
#
# Your score: 1/1
#
# ### Question 2:
# What did Gregory Mendel use to test genetic crossovers?
# A) Cats
# B) Peas
# C) Flowers
# D) Parrots
#
# What's your answer? (A, B, C, or D)
# You (write 'stop' to stop):  Peas
# 21:11:44.002   agent run
# 21:11:44.002     chat gpt-4o-mini
# Correct again! 🎉
#
# Gregory Mendel used peas to test genetic crossovers. He is known as the father of modern genetics for his experiments in heredity with pea plants, which helped him formulate the laws of inheritance. Fun fact: Mendel's work went largely unrecognized during his lifetime, and it wasn't until decades later that his contributions to genetics were acknowledged.
#
# Your score: 2/2
#
# ### Question 3:
# What is the standard SI unit for temperature?
# A) Fahrenheit
# B) Celsius
# C) Kelvin
# D) Rankine
#
# What's your answer? (A, B, C, or D)
# You (write 'stop' to stop):  Celsius
# 21:11:55.352   agent run
# 21:11:55.355     chat gpt-4o-mini
# That's incorrect. 😞
#
# The correct answer is **Kelvin**. The Kelvin scale is the standard unit of temperature in the International System of Units (SI), and it starts at absolute zero. Fun fact: 0 Kelvin is equivalent to -273.15°C, which is the point where all molecular motion stops!
#
# Your score: 2/3
#
# ### Question 4:
# Who is the chemical element Curium named after?
# A) The Curiosity Rover
# B) Marie & Pierre Curie
# C) Curious George
# D) Stephen Curry
#
# What's your answer? (A, B, C, or D)
# You (write 'stop' to stop):  Marie & Pierre Curie
# 21:12:11.455   agent run
# 21:12:11.459     chat gpt-4o-mini
# Correct! 🎉
#
# The chemical element Curium is named after Marie and Pierre Curie, who were pioneers in the study of radioactivity. They made groundbreaking discoveries, including the elements polonium and radium. Fun fact: Marie Curie was the first woman to win a Nobel Prize and remains the only person to win in two different scientific fields—Physics and Chemistry!
#
# Your score: 3/4
#
# ### Question 5:
# What name is given to all baby marsupials?
# A) Calf
# B) Pup
# C) Joey
# D) Cub
#
# What's your answer? (A, B, C, or D)
# You (write 'stop' to stop):  Joey
# 21:12:21.039   agent run
# 21:12:21.041     chat gpt-4o-mini
# Correct again! 🎉
#
# All baby marsupials are called **joeys**. This term is used for the young of marsupials like kangaroos, koalas, and wombats. Fun fact: A joey is born extremely underdeveloped and crawls into its mother's pouch, where it continues to grow and develop.
#
# Your final score: 4/5
#
# Great job! Would you like to play again or do something else?
# You (write 'stop' to stop):  stop

# %%
# Querying trace data 
from logfire.query_client import LogfireQueryClient
logfire_query_client = LogfireQueryClient(read_token='TOKEN_NUMBER')

trace_rows = logfire_query_client.query_json_rows(
    sql="""
    SELECT
        trace_id,
        start_timestamp,
        duration
    FROM records
    WHERE span_name = 'agent run'
    ORDER BY start_timestamp DESC
    LIMIT 2
    """
)

# %%
trace_ids = [r['trace_id'] for r in trace_rows['rows']]
trace_ids
# Out:
# ['019cd43972f0f18c536ecb4597cf9338', '019cd43972f0f18c536ecb4597cf9338']

# %%
trace_id = trace_ids[0]

run_row = logfire_query_client.query_json_rows(
    sql=f"""
    SELECT
        attributes->'pydantic_ai.all_messages' as all_messages,
        attributes->>'gen_ai.usage.input_tokens' as input_tokens,
        attributes->>'gen_ai.usage.output_tokens' as output_tokens
    FROM records
    WHERE trace_id = '{trace_id}'
      AND span_name = 'agent run'
    ORDER BY start_timestamp DESC
    LIMIT 1
    """
)

# %%
all_messages = run_row['rows'][0]
all_messages['all_messages'][0]
# Out:
# {'role': 'user',
#  'parts': [{'type': 'text',
#    'content': "Let's play 5 easy questions from Science & Nature"}]}

# %%
{'role': 'user',
 'parts': [{'type': 'text',
   'content': 'What metrics does Evidently support?'}]}
# Out:
# {'role': 'user',
#  'parts': [{'type': 'text',
#    'content': 'What metrics does Evidently support?'}]}
